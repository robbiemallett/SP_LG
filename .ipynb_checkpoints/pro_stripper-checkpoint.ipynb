# %%
import h5py
import pandas as pd
import numpy as np
from track_utils import lonlat_to_xy, xy_to_lonlat
from pyproj import Proj, transform
from track_utils import plot_track

# %%
f = h5py.File('2011.h5', 'r')

# %%
track_keys = list(f.keys())

# %%
sample_track_no = 30500

for key in track_keys[sample_track_no:sample_track_no+1]:
    track = np.array(f[key])

# %%
lonlist, latlist = xy_to_lonlat(track[:,0],track[:,1])

# print(list(zip(lonlist,latlist)))

plot_track(array1=lonlist,array2=latlist,xy=False)
