# %%
import h5py
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import psutil
from tqdm import tqdm_notebook as tqdm
import time
import pro_utils
import os
import time
import cartopy.crs as ccrs
import cartopy
from pandas.plotting import register_matplotlib_converters
import SP_utils
from pyproj import Proj, transform
import pandas as pd
import dill
from dill import Pickler, Unpickler
import shelve
shelve.Pickler = Pickler
shelve.Unpickler = Unpickler
import smrt_utils
import track_utils
from netCDF4 import Dataset
import logging
import datetime

def xy_to_lonlat(x, y):
    
    EASE_Proj = Proj(init='epsg:3408')
    WGS_Proj = Proj(init='epsg:4326')
    lon, lat = transform(EASE_Proj, WGS_Proj, x, y)
    return (lon, lat)

# %%
with h5py.File('SP_LG_Output/biggest_yet2016.hdf5', 'r') as f:
    
    track_keys = list(f.keys())
    
    print(track_keys)
    

# for key in track_keys:
    
#     data = pd.read_hdf('SP_LG_Output/results2016.hdf5', key=key, mode='r')
        
#     if data.shape[0] > 210:
#         print(key)

#         plt.plot(data.index,data['snow_depth'],alpha=0.3)
    
#     plt.xticks(rotation=270)
    
#     plt.show()
# Out:
# ['10001', '1001', '10026', '10051', '10076', '101', '10101', '10126', '10151', '10176', '10201', '10226', '10251', '10276', '10301', '10326', '10351', '10376', '10401', '10426', '10451', '1051', '10551', '10576', '10601', '10626', '10651', '10676', '10701', '10726', '10751', '10776', '10801', '10826', '10851', '10876', '10901', '10926', '10951', '10976', '11001', '1101', '11026', '11051', '11076', '11101', '11126', '11176', '11201', '11226', '11251', '11276', '11301', '11326', '11351', '11376', '11401', '11426', '11451', '11476', '11501', '1151', '11526', '11551', '11576', '11601', '11626', '11651', '11676', '11701', '11726', '11751', '1176', '11776', '11801', '11826', '11851', '11876', '11901', '11926', '11951', '11976', '12001', '1201', '12026', '12051', '12076', '12101', '12126', '12151', '12176', '12201', '12226', '12251', '1226', '12276', '12301', '12326', '12351', '12376', '12401', '12426', '12451', '12476', '12501', '1251', '12526', '12551', '12576', '126', '12601', '12626', '
# ...

# %%
# Out:
#             snow_depth  snow_density  ice_thickness  \
# date
# 2016-08-31      0.0100        280.80         0.9613
# 2016-08-31      0.0100        308.10         0.9751
# 2016-09-01      0.0100        294.50         0.9830
# 2016-09-02      0.0304        211.85         0.9860
# 2016-09-03      0.0264        222.65         0.9875
#
#                                              coords
# date
# 2016-08-31          [877363.375, 300810.2999999998]
# 2016-08-31          [877363.375, 300810.2999999998]
# 2016-09-01        [875730.4048, 301068.13739999983]
# 2016-09-02  [874097.4346000002, 301325.97479999985]
# 2016-09-03  [872464.4644000002, 301583.81219999987]

# %%
from tqdm.auto import tqdm, trange

key = '1151'

data = pd.read_hdf('SP_LG_Output/11512016.hdf5', key=key, mode='r')

tb37 = data["Tb(37, 'V')"]
tb19 = data["Tb(19, 'V')"]

data['GR'] = (tb37-tb19)/(tb37+tb19)

data.head()



x_coords = [float(x[0]) if np.isnan(x).any() == False else x for x in data['coords']]
y_coords = [float(x[1]) if np.isnan(x).any() == False else x for x in data['coords']]
snow_depth = [x if np.isnan(x).any() == False else x for x in data['snow_depth']]
GR = [x if np.isnan(x).any() == False else x for x in data['GR']]
timeline = [x for x in data.index]

lon_list, lat_list = xy_to_lonlat(x_coords,y_coords)


gif_dir = '/home/robbie/Dropbox/Modelling/SP_LG/track_gif/'
    

for day in trange(1, len(lon_list)):

    fig = plt.figure(figsize=(6,6))
    ax = plt.axes(projection=ccrs.NorthPolarStereo())

    ax.add_feature(cartopy.feature.LAND, edgecolor='black',zorder=1)

    ax.set_extent([-180, 180, 90, 72], ccrs.PlateCarree())

    plt.scatter(lon_list[:day],
                lat_list[:day],
                transform=ccrs.PlateCarree(),
                zorder=0,
                c=snow_depth[:day],
                vmax=0.4,
                vmin=0,
                s=15)

    plt.scatter(lon_list[day],
            lat_list[day],
            transform=ccrs.PlateCarree(),
            zorder=0,
            vmax=0.4,
            vmin=0,
            facecolors='none',
            edgecolors='k',
            s=15)

    cb = plt.colorbar(pad=0.01,shrink=0.86)
    cb.set_label(label='Snow Depth (m)',fontsize='xx-large')

    day_pad = str(day).zfill(3)
    
    f_name = f'{gif_dir}{day_pad}map.png'
    
    plt.tight_layout()
    
    plt.savefig(f'{f_name}',dpi=135)
#     plt.show()
    plt.close()

    convert_string = f'convert {f_name} {gif_dir}{day_pad}map.gif'
    
    ! {convert_string}
    
    break
    
# remove_string = f'rm {gif_dir}*.png'
# ! {remove_string}

# %%
for day in trange(1, len(lon_list)):


    fig, ax1 = plt.subplots(figsize=(8,5))

    color = 'crimson'

    l1 = ax1.plot(timeline[:day],snow_depth[:day],color=color,label='Depth')[0]
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.set_ylabel('Snow Depth (m)',fontsize='xx-large',color=color)
    plt.xticks(rotation=90,fontsize='large')
    plt.yticks(fontsize='large')
    ax1.set_ylim(0,0.35)

    ax1.set_xlim(timeline[0],timeline[-1])


    ax2 = ax1.twinx()

    l2 = ax2.plot(timeline[:day],GR[:day],color='darkblue',label='37 GHz')[0]

    ax2.tick_params(axis='y', labelcolor='darkblue')
    ax2.invert_yaxis()
    plt.yticks(fontsize='large')
    ax2.set_ylabel('Gradient Ratio',fontsize='xx-large',color='darkblue')
    ax2.set_ylim(0,-0.35)
    line_labels = ['Depth', 'Gradient Ratio']
    fig.legend([l1, l2],labels=line_labels,loc='lower right',borderaxespad=6.5,fontsize='large')
#     plt.gcf().subplots_adjust(bottom=0.18)
    
    day_pad = str(day).zfill(3)
    
    f_name = f'{gif_dir}{day_pad}lines.png'
    
    plt.tight_layout()
    
    plt.savefig(f'{f_name}',dpi=135)
#     plt.show()

    
#     plt.close()

    convert_string = f'convert {f_name} {gif_dir}{day_pad}lines.gif'
    
    ! {convert_string}
    
    
    
# remove_string = f'rm {gif_dir}*.png'
# ! {remove_string}

# %%
gif_dir = '/home/robbie/Dropbox/Modelling/SP_LG/track_gif/'

for day in trange(1, len(lon_list)):
    
    day_pad = str(day).zfill(3)
    
    f_name = f'{gif_dir}{day_pad}'
    
    merge_string = f'convert -density 400 {f_name}lines.gif {f_name}map.gif -gravity center +append {f_name}_m.gif'
    
    ! {merge_string}
    
    break

# remove_string = f'rm {gif_dir}*lines.gif'
# ! {remove_string}
# remove_string = f'rm {gif_dir}*map.gif'
# ! {remove_string}
# Out:
# ...
# convert-im6.q16: unable to open image `/home/robbie/Dropbox/Modelling/SP_LG/track_gif/001lines.gif': No such file or directory @ error/blob.c/OpenBlob/2701.

# %%
fig, ax1 = plt.subplots(figsize=(8,5))


l1 = ax1.plot(data.index,data['snow_depth'],color='crimson',label='Snow')[0]
l2 = ax1.plot(data.index,data['ice_thickness'],color='darkblue',label='Ice')[0]
ax1.tick_params(axis='y')
ax1.set_ylabel('Thickness (m)',fontsize='xx-large',color='k')
plt.xticks(rotation=90,fontsize='large')
plt.yticks(fontsize='large')

plt.legend(fontsize='x-large')

plt.gcf().subplots_adjust(bottom=0.18)

plt.savefig('/home/robbie/Desktop/thickness',dpi=500)

# %%
x = [1,2,3,4]
np.nanmean(x)
# Out:
# 2.5

# %%
start_date = datetime.date(year=2016,month=8,day=31)
end_date = datetime.date(year=2017,month=5,day=1)
delta = end_date - start_date
date_list = [start_date + datetime.timedelta(days=x) for x in range(delta.days)]

df_dates = pd.DataFrame(date_list,columns=['date'])
df_dates.set_index(['date'], inplace=True, drop=False)

with h5py.File('SP_LG_Output/biggest_yet2016.hdf5', 'r') as f:
    track_keys = list(f.keys())
    num_keys = len(track_keys)

array_to_fill = np.empty((3,num_keys,delta.days+31), dtype = np.float32)

print(array_to_fill.shape)
    
for i in trange(len(track_keys)):

    data = pd.read_hdf('SP_LG_Output/biggest_yet2016.hdf5', key=track_keys[i], mode='r')

    df = df_dates.join(data[['snow_depth','coords']])
    
    x_coords = [float(x[0]) if np.isnan(x).any() == False else x for x in df['coords']]
    y_coords = [float(x[1]) if np.isnan(x).any() == False else x for x in df['coords']]
    
    lon_list, lat_list = xy_to_lonlat(x_coords,y_coords)
   
    array_to_fill[0,i,30:] = lon_list
    array_to_fill[1,i,30:] = lat_list
    array_to_fill[2,i,30:] = df['snow_depth']
# Out:
#   0%|          | 8/1931 [00:00<00:24, 77.33it/s]
# (3, 1931, 274)
# 100%|██████████| 1931/1931 [00:19<00:00, 99.12it/s]

# %%
gif_timestep = 1
gif_dir = '/home/robbie/Dropbox/Modelling/SP_LG/gifs/'


for day in trange(1,delta.days+30,gif_timestep):


    # Make a plot for a given timestep:

    fig = plt.figure(figsize=(5,5))
    ax = plt.axes(projection=ccrs.NorthPolarStereo())

    ax.add_feature(cartopy.feature.LAND, edgecolor='black',zorder=1)

    ax.set_extent([-180, 180, 90, 66], ccrs.PlateCarree())



    # for day in range(0,delta.days+1,1):

    line_length = 30

    for track_num in range(0,num_keys,1):

        depth = array_to_fill[2, track_num, day:day + line_length]
        lon = array_to_fill[0, track_num, day:day + line_length]
        lat = array_to_fill[1, track_num, day:day + line_length]

        if (np.isnan(depth).all() == False) and (depth.size != 0):
    #         print(depth)    
            plt.scatter(lon,
                        lat,
                        transform=ccrs.PlateCarree(),
                        zorder=0,
                        c=depth,
                        vmax=0.4,
                        vmin=0,
                        s=18)
        
    
    plt.annotate(f'Day: {day}', xy = (0.03,0.9), xycoords = 'axes fraction', fontsize='xx-large')
    
    cb = plt.colorbar(pad=0.01,shrink=0.86)
    cb.set_label(label='Snow Depth (m)',fontsize='xx-large')
    
    day_pad = str(day).zfill(3)
    
    f_name = f'{gif_dir}{day_pad}.png'
        
    plt.savefig(f_name,dpi=135, bbox_inches='tight')
#     plt.show()
    plt.close()
#     break
    convert_string = f'convert {gif_dir}{day_pad}.png {gif_dir}{day_pad}.gif'
    
    ! {convert_string}
# Out:
#   0%|          | 0/272 [00:00<?, ?it/s]
#
#
#
#   0%|          | 1/272 [00:06<28:12,  6.25s/it]
#
#
#
#   1%|          | 2/272 [00:12<28:26,  6.32s/it]
#
#
#
#   1%|          | 3/272 [00:19<28:16,  6.31s/it]
#
#
#
#   1%|▏         | 4/272 [00:25<28:22,  6.35s/it]
#
#
#
#   2%|▏         | 5/272 [00:31<28:11,  6.33s/it]
#
#
#
#   2%|▏         | 6/272 [00:37<27:53,  6.29s/it]
#
#
#
#   3%|▎         | 7/272 [00:54<40:46,  9.23s/it]
#
#
#
#   3%|▎         | 8/272 [01:00<37:34,  8.54s/it]
#
#
#
#   3%|▎         | 9/272 [01:07<34:32,  7.88s/it]
#
#
#
#   4%|▎         | 10/272 [01:14<33:19,  7.63s/it]
#
#
#
#   4%|▍         | 11/272 [01:20<31:34,  7.26s/it]
#
#
#
#   4%|▍         | 12/272 [01:28<31:32,  7.28s/it]
#
#
#
#   5%|▍         | 13/272 [01:34<30:01,  6.96s/it]
#
#
#
#   5%|▌         | 14/272 [01:40<28:56,  6.73s/it]
#
#
#
#   6%|▌         | 15/272 [01:47<29:45,  6.95s/it]
#
#
#
#   6%|▌         | 16/272 [01:54<28:58,  6.79s/it]
#
#
#
# ...

# %%
print(delta)
# Out:
# 243 days, 0:00:00

# %%
day = 209
for track_num in range(0,num_keys,1):

    depth = array_to_fill[2, track_num, day:day + line_length]
    lon = array_to_fill[0, track_num, day:day + line_length]
    lat = array_to_fill[1, track_num, day:day + line_length]

    if (np.isnan(depth).all() == False):
        print(depth)
# Out:
# [0.2292 0.2485 0.242  0.2359 0.2293 0.2275 0.2255 0.2204 0.2189 0.2178
#  0.2167 0.2155 0.2145 0.2134 0.2104 0.2079 0.2065 0.2058 0.2049 0.2028
#  0.1955 0.1935 0.1922 0.186  0.2052 0.2031 0.2015 0.2004 0.1994 0.1987
#  0.1979 0.1971 0.1962 0.195     nan]
# [0.2633 0.3093 0.2889 0.2848 0.281  0.3022 0.2932 0.2879 0.2839 0.2809
#  0.2783 0.2762 0.2745 0.273  0.2711 0.2695 0.2681 0.2666 0.2654 0.261
#  0.2736 0.2701 0.2581 0.2543 0.2501 0.2647 0.2593 0.2559 0.2525 0.2496
#  0.2471 0.2443 0.2409 0.2389    nan]
# [0.3065 0.2982 0.2927 0.2905 0.3301 0.3237 0.3212 0.3198 0.3173 0.3149
#  0.3127 0.3291 0.3236 0.3175 0.3154 0.3134 0.33   0.3237 0.3173 0.3145
#  0.3122 0.3099 0.3013 0.2977 0.3193 0.3158 0.3098 0.3058 0.3031 0.3011
#  0.2984 0.2919 0.2868 0.282     nan]
# [0.374  0.365  0.3966 0.3946 0.3929 0.3912 0.3897 0.3866 0.3826 0.3808
#  0.3794 0.3781 0.3768 0.3754 0.3735 0.3717 0.4034 0.394  0.3813 0.3784
#  0.3754 0.3729 0.3699 0.3674 0.3647 0.3626 0.3603 0.3582 0.3567 0.3552
# ...

# %%
year = 2016
track_no = 48600

def run_smrt_from_dill(year,track_no):

    output_dir = f"/home/robbie/Dropbox/Modelling/SP_LG/SP_LG_Output/"

    with shelve.open(f'{output_dir}/media_{year}', 'r') as f:

        mediums_list = f[str(track_no)]
    
    print('Running SMRT')
    
    smrt_res = run_media_series(mediums_list, [19e9, 37e9])
    
    print('SMRT run complete')

    smrt_df = process_smrt_results(smrt_res,[19e9, 37e9])

    return(smrt_df)

def combine_smrt_sp_frames(smrt_df,track_no)
    
    SP_df = pd.read_hdf(f'{output_dir}track_df.hdf5', key=str(track_no), mode='r')

    smrt_df['date'] = SP_df.index

    smrt_df.set_index(['date'], inplace=True, drop=True)

    combined = pd.concat([SP_df,smrt_df],axis=1).copy()

    combined.to_hdf(f'{output_dir}track_df_comb.hdf5', key=str(track_no), mode='w')
    
    return(combined)

# %%
run_smrt_and_combine(year,track_no)

# Now read the combined result out

comb_res = pd.read_hdf(f'{output_dir}track_df_comb.hdf5', key=str(track_no), mode='r')

comb_res.head()
# Out:
# Running SMRT
# SMRT run complete
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-7a5135e02f0f> in <module>
# ----> 1 run_smrt_and_combine(year,track_no)
#       2
#       3 # Now read the combined result out
#       4
#       5 comb_res = pd.read_hdf(f'{output_dir}track_df.hdf5', key=str(track_no), mode='r')
#
# <ipython-input-44-ad36dce1cc1a> in run_smrt_and_combine(year, track_no)
#      26     combined = pd.concat([SP_df,smrt_df],axis=1).copy()
#      27
# ---> 28     combined.to_hdf(f'{output_dir}track_df.hdf5', key=str(track_no), mode='w')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2503             data_columns=data_columns,
#    2504             errors=errors,
# ...

# %%
snowpack_data =

# %%
print(snowpack_data.shape)
snowpack_data.head()
# Out:
# (207, 4)
#             snow_depth  snow_density  ice_thickness  \
# date
# 2016-10-06        0.01         279.0         0.1999
# 2016-10-06        0.01         279.0         0.2077
# 2016-10-07        0.01         279.2         0.2175
# 2016-10-08        0.01         239.5         0.2263
# 2016-10-09        0.01         238.8         0.2418
#
#                                              coords
# date
# 2016-10-06             [-755467.163075, 879082.291]
# 2016-10-06             [-755467.163075, 879082.291]
# 2016-10-07  [-758908.5761500001, 880801.2069999998]
# 2016-10-08  [-762349.9892250001, 882520.1229999998]
# 2016-10-09  [-765791.4023000002, 884239.0389999998]

# %%
# Out:
#             snow_depth  snow_density  ice_thickness  \
# date
# 2016-10-06        0.01         279.0         0.1999
# 2016-10-06        0.01         279.0         0.2077
# 2016-10-07        0.01         279.2         0.2175
# 2016-10-08        0.01         239.5         0.2263
# 2016-10-09        0.01         238.8         0.2418
#
#                                              coords  Tb(19, 'V')  Tb(37, 'V')  \
# date
# 2016-10-06             [-755467.163075, 879082.291]   257.004513   259.383169
# 2016-10-06             [-755467.163075, 879082.291]   259.155645   260.206915
# 2016-10-07  [-758908.5761500001, 880801.2069999998]   260.022822   260.880168
# 2016-10-08  [-762349.9892250001, 882520.1229999998]   257.186389   257.898178
# 2016-10-09  [-765791.4023000002, 884239.0389999998]   258.436814   259.270291
#
#             Tb(19, 'H')  Tb(37, 'H')
# date
# 2016-10-06   219.076225   223.789371
# 2016-10-06   229.035940   230.645840
# 2016-10-07   229.623318   231.075268
# ...

# %%
import numpy as np
import pro_utils
from smrt import make_snowpack, make_ice_column, make_model, sensor_list
import os
import sys
import logging
import itertools
import pandas as pd
# from smrt.utils import dmrt_qms_legacy

def process_smrt_results(smrt_res,frequencies):
    
    dict_of_lists = {}

    if smrt_res != None:

        for pol in ['V', 'H']:
            for freq in frequencies:
                dict_of_lists['Tb'+str((int(freq/1e9),pol))] = smrt_res.Tb_as_dataframe(polarization=pol,frequency=freq)['Tb']

    df = pd.DataFrame(dict_of_lists)

    return(df)



def prep_medium(snowpro,
                brine_inc_corr_len=1.0e-3):

    snow_df, ice_df = snowpro.snowframe, snowpro.iceframe


    # Establish correlation length using Vargel 2020

    SSA = 3/((0.917/2)*np.array(snow_df['optical equivalent grain size (mm)']))
    IVF = np.array(snow_df['ice volume fraction (%)'])/100
    snow_df['CL'] = 4 * np.divide(np.subtract(1, IVF), 917*SSA)

    snowpack = make_snowpack(thickness=snow_df['thickness_m'],

                             temperature=snow_df['element temperature (degC)'] + 273.15,

                             microstructure_model='exponential',

                             corr_length=snow_df['CL'],

                             density=snow_df['element density (kg m-3)'],

                             salinity=snow_df['bulk salinity (g/kg)'] / 1000)

    ice_col = make_ice_column(ice_type='firstyear',
                              thickness=ice_df['thickness_m'],
                              temperature=ice_df['element temperature (degC)'] + 273.15,
                              microstructure_model='exponential',
                              corr_length=np.array([brine_inc_corr_len] * len(ice_df['thickness_m'])),
                              brine_inclusion_shape='spheres',
                              salinity=ice_df['bulk salinity (g/kg)'] / 1000,
                              density=ice_df['element density (kg m-3)'],
                              add_water_substrate='ocean')

    medium = snowpack + ice_col

    return(medium)


def run_media_series(mediums_list,
                 frequencies,
                 solver='dort',
                 angle=55,
                 pol='V'):


    # create the sensor
    radiometer = sensor_list.passive(frequencies, angle, pol)

    n_max_stream = 32  # TB calculation is more accurate if number of streams is increased (currently: default = 32);

    m = make_model("iba", solver,
                   rtsolver_options={"n_max_stream": n_max_stream})

    # run the model for snow-covered sea ice:

    res = m.run(radiometer, mediums_list, progressbar=True)

    # CODE FOR SWITCHING TO DMRT IN EVENT OF DORT FAILURE:
    #
    # try:
    #     if solver == 'dort':
    #         m = make_model("iba", solver,
    #                        rtsolver_options={"n_max_stream": n_max_stream})
    #
    #         # run the model for snow-covered sea ice:
    #
    #         res = m.run(radiometer, mediums_list)
    #     elif solver == 'dmrt_qms':
    #         print('qms')
    #         res = dmrt_qms_legacy.run(radiometer,
    #                                   snowpack,
    #                                   dmrt_qms_path = '/home/robbie/DMRT-QMS/')
    # except:
    #     if solver == 'dort':
    #         logging.warning('Renormalisation failed - forcing...')
    #
    #         m = make_model("iba", solver,
    #                        rtsolver_options={"n_max_stream": n_max_stream,
    #                                          "phase_normalization": 'forced'})
    #
    #         # run the model for snow-covered sea ice:
    #         res = m.run(radiometer, medium)
    #     else:
    #         logging.error('QMS Failed')
    #         return(0)

    return (res)

# if __name__ == '__main__':
#     os.chdir("Snowpack_files")
#     result_list = run_track()
#     print(result_list)
